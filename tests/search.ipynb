# %%
import requests

query = 'Aline'

url = 'http://localhost:8001/search'

search_data = {
        "query": query,
        "limit": 10
    }

response = requests.post(f"{url}", json=search_data)
resultados = response.json()

print(resultados)
# Out:
# {'results': [{'page_content': 'Aline Fernanda Cadamuro\n\n26 anos\n\nPonta Grossa - PR\n\nNão informado\n\n(17) 99715-1829\n\n# Resumo profissional\n\nProfissional com experiência sólida em operações financeiras e dados, com foco em automação de processos, estruturação de dashboards em Power BI e integração de dados entre sistemas. Conhecimento em Python para ETL e consumo de APIs, além de domínio em SQL e ferramentas de análise. Vivência no setor da construção civil, com atuação em projetos estratégicos e comunicação com áreas técnicas e executivas.\n\n# Cargo(s) de interesse\n\nAnalista de Dados, Analista Financeiro\n\n# Experiência profissional\n\n# ANALISTA SR. DE OPERAÇÕES FINANCEIRAS\n\nPrestes Construtora e Incorporadora Ltda\n\n# Descrição\n\n- Responsável pelo controle e planejamento do fluxo de caixa da empresa, com atuação direta em contas a pagar, contas a receber, conciliações bancárias e previsões financeiras;\n- Desenvolvimento de dashboards interativos e relatórios fi
# ...
